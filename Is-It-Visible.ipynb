# %%
from astroplan import Observer

# %%
siding = Observer.at_site('siding spring observatory') # Add input prompt here.

# %%
from astropy.coordinates import SkyCoord

# %%
from astroplan import FixedTarget

# %%
object = FixedTarget.from_name("wasp-17") # Add input prompt here.

# %%
from astropy.time import Time

# %%
time = Time.now()

# %%
siding.target_is_up(time,vega)
# Out:
# True

# %%
import numpy as np
import astropy.units as u

# %%
object_rise = siding.target_rise_time(time, vega) + 5*u.minute
object_set = siding.target_set_time(time, vega) - 5*u.minute

# %%
from astroplan import download_IERS_A
download_IERS_A()
sunset_tonight = siding.sun_set_time(time, which='nearest')

# %%
sunset_tonight.iso
# Out:
# '2018-12-08 08:54:29.476'

# %%
from astroplan.plots import plot_airmass 
import matplotlib.pyplot as plt 

plot_airmass(object, siding, time) 
plt.title("Visibility Chart")
plt.legend(loc=1, bbox_to_anchor=(1, 1)) 
plt.show()
